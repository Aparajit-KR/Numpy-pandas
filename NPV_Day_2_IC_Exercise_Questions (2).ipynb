# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="20%">
#             <img src="GL-2.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Inclass - Lab<br> (Day 2)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Table of Content
# 1. **[Data Structures with Examples](#Data_Structures)**
# 2. **[Create and Manipulate the DataFrames](#create_manipulate)**
# 3. **[Sort](#sorting)**
# 4. **[Rank](#ranking)**

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='Data_Structures'></a>
# ## 1. Data Structures with Examples:

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Write a program to create a dataframe from list of lists
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below nested list:**<br>
#
#         data = [['Joy', 21], ['Mia', 15], ['Sam', 14]]

# %%
# type your code here
import numpy as np
import pandas as pd
datas = [['Joy', 21], ['Mia', 15], ['Sam', 14]]
pd.DataFrame(datas)
# Out:
#      0   1
# 0  Joy  21
# 1  Mia  15
# 2  Sam  14

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Extract the second word from the given string
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below string:**<br>
#
#     sentence = 'Be confident and be yourself'

# %%
# type your code here
sentence = 'Be confident and be yourself'
s=sentence.split(" ")
a=pd.Series(s)
a[1]
# Out:
# 'confident'

# %% [markdown]
# <a id='create_manipulate'></a>
# ## 2. Create and Manipulate the DataFrames:

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Split the 'Name' column into two separate columns as First_Name and Last_Name </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>3200</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>4500</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>3600</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>5596</td>
# </tr>
#
# </table>

# %%
# type your code here
df=pd.DataFrame({'Name':['Emma Larter','Mia Junior','Sophia Depp','James Smith'],
   'Salary':[3200,4500,3600,5596]})
df[['fname','lname']]=df['Name'].str.split(expand = True)
df.drop(columns='Name')
# Out:
#    Salary   fname   lname
# 0    3200    Emma  Larter
# 1    4500     Mia  Junior
# 2    3600  Sophia    Depp
# 3    5596   James   Smith

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Select the rows from below dataframe where marks are less than 60 </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Marks</th>
# </tr>
# <tr>
# <td>John</td>
# <td>90</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>50</td>
# </tr>
# <tr>
# <td>Jonny</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>55</td>
# </tr>
#
# </table>

# %%
# type your code here
Name=[('John',90),('Robert',50),('Johnny',89),('Mia',55)]
s=pd.DataFrame(data=Name,columns=['Name','Marks'])
s[s['Marks']>60]
# Out:
#      Name  Marks
# 0    John     90
# 2  Johnny     89

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Write a program to select the rows where the sales are higher than 60000 for Mumbai </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
a = {'Store':['A','B','A','C','D','A','D','A','C','B'],
                'Location':['Mumbai','Pune','Hyderbad','Mumbai','Pune','Delhi','Hyderbad','Pune','Mumbai','Pune'],
                'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
a=pd.DataFrame(a)
a[ (a['Location']=='Mumbai') & (a['Sales']>60000)]
# Out:
#   Store Location  Sales
# 3     C   Mumbai  90000
# 8     C   Mumbai  89000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Write a program to select stores located in Hyderabad</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
a = {'Store':['A','B','A','C','D','A','D','A','C','B'],
                'Location':['Mumbai','Pune','Hyderbad','Mumbai','Pune','Delhi','Hyderbad','Pune','Mumbai','Pune'],
                'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
a=pd.DataFrame(a)
a[a['Location']=='Hyderbad']
# Out:
#   Store  Location  Sales
# 2     A  Hyderbad  50000
# 6     D  Hyderbad  85000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Write a program to replace the 'Store' column with the values A, B, C, and D with Store_A,  Store_B, Store_C and Store_D respectively </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
a = {'Store':['A','B','A','C','D','A','D','A','C','B'],
                'Location':['Mumbai','Pune','Hyderbad','Mumbai','Pune','Delhi','Hyderbad','Pune','Mumbai','Pune'],
                'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
a=pd.DataFrame(a)
a['Store']=a['Store'].replace({'A':'Store_A','B':'Store_B','C':'Store_C','D':'Store_D'})
a
# Out:
#      Store  Location  Sales
# 0  Store_A    Mumbai  40000
# 1  Store_B      Pune  45000
# 2  Store_A  Hyderbad  50000
# 3  Store_C    Mumbai  90000
# 4  Store_D      Pune  89000
# 5  Store_A     Delhi  87000
# 6  Store_D  Hyderbad  85000
# 7  Store_A      Pune  78000
# 8  Store_C    Mumbai  89000
# 9  Store_B      Pune  70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Create a dataframe in pandas using the given list.
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the below list**
#
#         city = ['Delhi', 'Mumbai', 'Chennai', 'Kolkata']

# %%
# type your code here
city = ['Delhi', 'Mumbai', 'Chennai', 'Kolkata']
pd.DataFrame(city)
# Out:
#          0
# 0    Delhi
# 1   Mumbai
# 2  Chennai
# 3  Kolkata

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Save a given dataframe to a csv file
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
a = {'Store':['A','B','A','C','D','A','D','A','C','B'],
                'Location':['Mumbai','Pune','Hyderbad','Mumbai','Pune','Delhi','Hyderbad','Pune','Mumbai','Pune'],
                'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
a=pd.DataFrame(a)
a.to_csv("data.csv")

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the maximum sales for each store
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
a = {'Store':['A','B','A','C','D','A','D','A','C','B'],
                'Location':['Mumbai','Pune','Hyderbad','Mumbai','Pune','Delhi','Hyderbad','Pune','Mumbai','Pune'],
                'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
a=pd.DataFrame(a)

a[['Store','Sales']].groupby(by='Store').max()
# Out:
#        Sales
# Store
# A      87000
# B      70000
# C      90000
# D      89000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Write a program to select all columns, except the 'Location' from the given dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
# METHOD 1
a = {'Store':['A','B','A','C','D','A','D','A','C','B'],
                'Location':['Mumbai','Pune','Hyderbad','Mumbai','Pune','Delhi','Hyderbad','Pune','Mumbai','Pune'],
                'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
a=pd.DataFrame(a)

a.iloc[::,[0,2]]
# Out:
#   Store  Sales
# 0     A  40000
# 1     B  45000
# 2     A  50000
# 3     C  90000
# 4     D  89000
# 5     A  87000
# 6     D  85000
# 7     A  78000
# 8     C  89000
# 9     B  70000

# %%
# METHOD 2
a.drop(columns='Location')
# Out:
#   Store  Sales
# 0     A  40000
# 1     B  45000
# 2     A  50000
# 3     C  90000
# 4     D  89000
# 5     A  87000
# 6     D  85000
# 7     A  78000
# 8     C  89000
# 9     B  70000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Write a program to insert a given column at the second position in a dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Age</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>34</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>59</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>32</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>40</td>
# </tr>
#
# </table>
#
# **Add the variable 'Salary' as second column**<br>
#
#             Salary = [35000, 24000, 55000, 40000]

# %%
# type your code here
a={"Name": ['Emma Larter','Mia Junior','Sophia Depp','James Smith'],
  'Age':[34,59,32,40]}
df=pd.DataFrame(a)
df.insert(1,'Salary',[35000,24000,55000,40000])
df
# Out:
#           Name  Salary  Age
# 0  Emma Larter   35000   34
# 1   Mia Junior   24000   59
# 2  Sophia Depp   55000   32
# 3  James Smith   40000   40

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Write a program to get the third observation of the given dataframe
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Age</th>
# </tr>
# <tr>
# <td>Emma Larter</td>
# <td>34</td>
# </tr>
# <tr>
# <td>Mia Junior</td>
# <td>59</td>
# </tr>
# <tr>
# <td>Sophia Depp</td>
# <td>32</td>
# </tr>
# <tr>
# <td>James Smith</td>
# <td>40</td>
# </tr>
# </table>

# %%
# type your code here
a={"Name": ['Emma Larter','Mia Junior','Sophia Depp','James Smith'],
  'Age':[34,59,32,40]}
df=pd.DataFrame(a)
df.iloc[[2]]
# Out:
#           Name  Age
# 2  Sophia Depp   32

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Write a program to create a dataframe from the provided lists</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the following lists to create your arrays:**
#
#             columns = ["Science", "Maths", "English"]
#
#             marks = [[55, 78, 88], [93, 63, 83],[94, 74, 64]]
#
# **Hint:** Convert the list marks into an array

# %%
# type your code here
my_columns = np.array(["Science", "Maths", "English"])
marks = np.array([[55, 78, 88], [93, 63, 83],[94, 74, 64]])
pd.DataFrame(data=marks,columns=my_columns)
# Out:
#    Science  Maths  English
# 0       55     78       88
# 1       93     63       83
# 2       94     74       64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Write a program to count total sales per store </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
a = {'Store':['A','B','A','C','D','A','D','A','C','B'],
                'Location':['Mumbai','Pune','Hyderbad','Mumbai','Pune','Delhi','Hyderbad','Pune','Mumbai','Pune'],
                'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
a=pd.DataFrame(a)
a[['Store','Sales']].groupby(by='Store').sum()
# Out:
#         Sales
# Store
# A      255000
# B      115000
# C      179000
# D      174000

# %% [markdown]
# <a id='sorting'></a>
# ## 3. Sort

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Write a program to sort the dataframe by 'Sales' in ascending order
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
import pandas as pd

Sales=pd.DataFrame({'Store' : ['A','B','A','C','D','A','D','A','C','D'],
                  'Location': ['Mumbai','Pune','Hyderabad','Mumbai','Pune','Delhi',
                              'Hyderabad','Pune','Mumbai','Pune'],
                    'Sales':['40000','45000','50000','90000','89000','87000',
                            '85000','78000','89000','70000']
                   }
                  )
Sales.sort_values(by=['Sales'],ascending=[True])
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 9     D       Pune  70000
# 7     A       Pune  78000
# 6     D  Hyderabad  85000
# 5     A      Delhi  87000
# 4     D       Pune  89000
# 8     C     Mumbai  89000
# 3     C     Mumbai  90000

# %%
#not directly assigning to dataframe
a = {'Store':['A','B','A','C','D','A','D','A','C','B'],
                'Location':['Mumbai','Pune','Hyderbad','Mumbai','Pune','Delhi','Hyderbad','Pune','Mumbai','Pune'],
                'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
a=pd.DataFrame(a)
a.sort_values(by='Sales')
# Out:
#   Store  Location  Sales
# 0     A    Mumbai  40000
# 1     B      Pune  45000
# 2     A  Hyderbad  50000
# 9     B      Pune  70000
# 7     A      Pune  78000
# 6     D  Hyderbad  85000
# 5     A     Delhi  87000
# 4     D      Pune  89000
# 8     C    Mumbai  89000
# 3     C    Mumbai  90000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Write a program to sort the dataframe by 'Store' in ascending order and by 'Sales' in descending order with respect to store simultaneously
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
a = {'Store':['A','B','A','C','D','A','D','A','C','B'],
                'Location':['Mumbai','Pune','Hyderbad','Mumbai','Pune','Delhi','Hyderbad','Pune','Mumbai','Pune'],
                'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
a=pd.DataFrame(a)
a.sort_values(by=['Store','Sales'],ascending=[True,False])
# Out:
#   Store  Location  Sales
# 5     A     Delhi  87000
# 7     A      Pune  78000
# 2     A  Hyderbad  50000
# 0     A    Mumbai  40000
# 9     B      Pune  70000
# 1     B      Pune  45000
# 3     C    Mumbai  90000
# 8     C    Mumbai  89000
# 4     D      Pune  89000
# 6     D  Hyderbad  85000

# %% [markdown]
# <a id='ranking'></a>
# ## 4. Rank

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Create a column 'Rank_sales' which contains the rank of each store based on sales of the product in ascending order
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# type your code here
a = {'Store':['A','B','A','C','D','A','D','A','C','B'],
                'Location':['Mumbai','Pune','Hyderbad','Mumbai','Pune','Delhi','Hyderbad','Pune','Mumbai','Pune'],
                'Sales':[40000,45000,50000,90000,89000,87000,85000,78000,89000,70000]}
a=pd.DataFrame(a)
x = a[['Store','Sales']].groupby(by='Store')[["Sales"]].sum()
x["Sales_rank"] = x["Sales"].rank()
x
# Out:
#         Sales  Sales_rank
# Store
# A      255000         4.0
# B      115000         1.0
# C      179000         3.0
# D      174000         2.0
